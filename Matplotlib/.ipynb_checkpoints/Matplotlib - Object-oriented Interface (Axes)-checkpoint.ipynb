# %% [markdown]
# ## Matplotlib - Object-oriented Interface (Axes)
# <PRE>
# 1. To begin with, we create a figure instance which provides an empty canvas.
# fig = plt.figure()
#
# 2. Now add axes to figure.
# The add_axes() method requires a list object of 4 elements.
#
# ax=fig.add_axes([0,0,1,1]
#
# <b>Corresponding to left, bottom, width and height of the figure. </b>
# Each number must be between 0 and 1
#
# 3. Set labels for x and y axis as well as title:
# ax.set_title("sine wave")
# ax.set_xlabel('angle')
# ax.set_ylabel('sine')
#
# 4. Invoke the plot() method of the axes object.
# ax.plot(x,y)

# %%
#Plotting useing Obj Oriented Interface
from matplotlib import pyplot as plt

import numpy as np

import math

#Creating the x and y axis values
x = np.arange(0, 2*math.pi, 0.05)
y = np.sin(x)

fig = plt.figure() #Creating the figure object

ax = fig.add_axes([0,0,1,1])  #Left, bottom, width and height of the axes
ax.plot(x,y)
ax.set_xlabel('angel')
ax.set_ylabel('sine')
ax.set_title('Sine wave')

plt.show()

# %% [markdown]
# # Why use the Object oriented interface
# While it is easy to quickly generate plots with the matplotlib.pyplot module, the use of object-oriented approach is recommended as it gives more control and customization of your plots. Most of the functions are also available in the matplotlib.axes.Axes class.
#
# The main idea behind using the more formal object-oriented method is to create figure objects and then just call methods or attributes off of that object. This approach helps better in dealing with a canvas that has multiple plots on it.

# %%
from matplotlib import pyplot as plt

y = [1, 4, 9, 16, 25,36,49, 64]
x1 = [1, 16, 30, 42,55, 68, 77, 88]
x2 = [1,6,12,18,28, 40, 52, 65]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

l1 = ax.plot(x1, y, 'y-')
l2 = ax.plot(x2, y, 'g--')

ax.legend(labels = ('tv', 'Smartphone'), loc = 'lower right')

ax.set_title("Advertisement effect on sales")
ax.set_xlabel('medium')
ax.set_ylabel('sales')
plt.show()
fig.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-075d6e3f0007> in <module>
#      17 ax.set_ylabel('sales')
#      18 plt.show()
# ---> 19 fig.save()
#
# AttributeError: 'Figure' object has no attribute 'save'
